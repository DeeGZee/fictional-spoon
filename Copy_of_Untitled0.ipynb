# %% [markdown]
# <a href="https://colab.research.google.com/github/DeeGZee/fictional-spoon/blob/main/Copy_of_Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !uname -a

# %%
# !git clone https://github.com/SkalskiP/yolov9.git
# Out:
# Cloning into 'yolov9'...
# remote: Enumerating objects: 147, done.
# remote: Total 147 (delta 0), reused 0 (delta 0), pack-reused 147
# Receiving objects: 100% (147/147), 607.53 KiB | 15.99 MiB/s, done.
# Resolving deltas: 100% (58/58), done.

# %%
# %cd yolov9
# Out:
# /content/yolov9

# %%
# !pip install -r requirements.txt -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 5.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 17.5 MB/s eta 0:00:00

# %%
# !ls -l ;pwd

# %%
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-c.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-e.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-c.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-e.pt

# %%
# %cd {HOME}/yolov9
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="D5hHlu1WXXNonGIXaUB9")
project = rf.workspace("roboflow-universe-projects").project("construction-site-safety")
version = project.version(27)
dataset = version.download("yolov7")
# Out:
# [Errno 2] No such file or directory: '{HOME}/yolov9'
# /content/yolov9
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.2/70.2 kB 3.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 10.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 12.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 9.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 12.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.7/86.7 kB 13.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.9.0.80
#     Uninstalling opencv-python-headless-4.9.0.80:
#       Successfully uninstalled opencv-python-headless-4.9.0.80
#   Attempting uninstall: idna
#     Found existing installation: idna 3.6
#     Uninstalling idna-3.6:
# ...

# %%
# !pwd
# !ls -l

# %%
cd  yolov9

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="D5hHlu1WXXNonGIXaUB9")
project = rf.workspace("roboflow-universe-projects").project("construction-site-safety")
version = project.version(27)
dataset = version.download("yolov7")

# %%
# !python train.py \
--batch 16 --epochs 20 --img 640 --device 0 --min-items 0 --close-mosaic 15 \
--data Construction-Site-Safety-27/data.yaml \
--weights ./{HOME}/weights/gelan-c.pt \
--cfg models/detect/gelan-c.yaml \
--hyp hyp.scratch-high.yaml
# Out:
# 2024-03-05 22:10:13.125109: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-05 22:10:13.125158: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-05 22:10:13.126461: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-05 22:10:14.115893: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...

# %%
# !find . -type f

# %%
# !find . -name gelan-c.pt
# Out:
# ./{HOME}/weights/gelan-c.pt

# %%
Image(filename=f"{HOME}/yolov9/runs/train/exp/val_batch0_pred.jpg", width=1000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-c7da1b39559e> in <cell line: 1>()
# ----> 1 Image(filename=f"{HOME}/yolov9/runs/train/exp/val_batch0_pred.jpg", width=1000)
#
# NameError: name 'Image' is not defined

# %%
from IPython.display import Image

# %%
Image(filename=f"/content/yolov9/runs/train/exp3/val_batch0_pred.jpg", width=1000)

# %%
ls -l /content/yolov9/runs/train/exp/val_batch0_pred.jpg
# Out:
# ls: cannot access '/content/yolov9/runs/train/exp/val_batch0_pred.jpg': No such file or directory

# %%
# !find . -name val_batch0_pred.jpg
# Out:
# ./runs/train/exp3/val_batch0_pred.jpg

# %%
# !find . -name "*.jpeg"

# %%
https://previews.123rf.com/images/lightfieldstudios/lightfieldstudios1704/lightfieldstudios170402469/75671369-workmen-with-level-tool.jpg

# %%
import cv2

# %%
Image(filename="https://previews.123rf.com/images/lightfieldstudios/lightfieldstudios1704/lightfieldstudios170402469/75671369-workmen-with-level-tool.jpg", width=1000)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-33-4a5b2428743f> in <cell line: 1>()
# ----> 1 Image(filename="https://previews.123rf.com/images/lightfieldstudios/lightfieldstudios1704/lightfieldstudios170402469/75671369-workmen-with-level-tool.jpg", width=1000)
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1229         self.retina = retina
#    1230         self.unconfined = unconfined
# -> 1231         super(Image, self).__init__(data=data, url=url, filename=filename,
#    1232                 metadata=metadata)
#    1233
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, metadata)
#     635             self.metadata = {}
#     636
# --> 637         self.reload()
# ...

# %%
image = cv2.imread('https://previews.123rf.com/images/lightfieldstudios/lightfieldstudios1704/lightfieldstudios170402469/75671369-workmen-with-level-tool.jpg')

# %%
cv2.imshow('Image', image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# DisabledFunctionError                     Traceback (most recent call last)
# <ipython-input-35-0206d4fe50d3> in <cell line: 1>()
# ----> 1 cv2.imshow('Image', image)
#       2 cv2.waitKey(0)
#       3 cv2.destroyAllWindows()
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_import_hooks/_cv2.py in wrapped(*args, **kwargs)
#      46   def wrapped(*args, **kwargs):
#      47     if not os.environ.get(env_var, False):
# ---> 48       raise DisabledFunctionError(message, name or func.__name__)
#      49     return func(*args, **kwargs)
#      50
#
# DisabledFunctionError: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow

# %%
from google.colab.patches import cv2_imshow

# %%
cv2.imshow('Image', image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# DisabledFunctionError                     Traceback (most recent call last)
# <ipython-input-37-0206d4fe50d3> in <cell line: 1>()
# ----> 1 cv2.imshow('Image', image)
#       2 cv2.waitKey(0)
#       3 cv2.destroyAllWindows()
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_import_hooks/_cv2.py in wrapped(*args, **kwargs)
#      46   def wrapped(*args, **kwargs):
#      47     if not os.environ.get(env_var, False):
# ---> 48       raise DisabledFunctionError(message, name or func.__name__)
#      49     return func(*args, **kwargs)
#      50
#
# DisabledFunctionError: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
